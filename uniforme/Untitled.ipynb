# %%
import pandas as pd
import matplotlib.pyplot as plt
from unidecode import unidecode
import re

# %%
bdoMAP = pd.read_csv('bdomap.csv',sep=',')

# %%
bdoMAP = bdoMAP.apply(lambda x: x.astype(str).str.upper())

# %%
bdoMAP['NODES'] = bdoMAP['NODES'].str.replace(' ','_',regex=False)
bdoMAP['NEIGHBORHOOD'] = bdoMAP['NEIGHBORHOOD'].str.replace(' ','_',regex=False)

# %%
bdoMAP
# Out:
#                          NODES CP     NODE TYPE LOCATION  \
# 0              WESTERN_GATEWAY  3       GATEWAY    EARTH
# 1              WESTERN_GATEWAY  3       GATEWAY    EARTH
# 2              WESTERN_GATEWAY  3       GATEWAY    EARTH
# 3                  HEIDEL_PASS  3       GATEWAY    EARTH
# 4                  HEIDEL_PASS  3       GATEWAY    EARTH
# 5                  HEIDEL_PASS  3       GATEWAY    EARTH
# 6                EPHERIA_RIDGE  1    CONNECTION    EARTH
# 7                EPHERIA_RIDGE  1    CONNECTION    EARTH
# 8               ELDER'S_BRIDGE  1    CONNECTION    EARTH
# 9               ELDER'S_BRIDGE  1    CONNECTION    EARTH
# 10              ELDER'S_BRIDGE  1    CONNECTION    EARTH
# 11              ELDER'S_BRIDGE  1    CONNECTION    EARTH
# 12   FOOT_OF_TERRMIAN_MOUNTAIN  1    CONNECTION    EARTH
# 13           MASK_OWL'S_FOREST  1    CONNECTION    EARTH
# 14           MASK_OWL'S_FOREST  1    CONNECTION    EARTH
# ...

# %%
bdoMAP.to_csv('bdomap.csv',sep=',')
